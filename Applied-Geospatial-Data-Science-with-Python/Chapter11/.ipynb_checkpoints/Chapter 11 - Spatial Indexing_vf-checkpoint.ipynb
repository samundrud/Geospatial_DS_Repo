# %% [markdown]
# # 1.0 Setup

# %% [markdown]
# ## 1.1 Package Imports

# %%
import geopandas as gpd
import pandas as pd
import time
from shapely.geometry import Point, Polygon, MultiPolygon
import osmnx as ox
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## 1.2 Data Import

# %%
# Setting the file path
path = '../Data/Data_pt1/'

# %%
# Reading in the data as a Pandas DataFrame
#REMINDER - The listings data must be downloaded from Inside Airbnb
listings = pd.read_csv(path + 'NY_Airbnb_Oct_2023/listings.csv.gz', compression='gzip', low_memory=False)

# Converting it to a GeoPandas DataFrame
listings_gpdf = gpd.GeoDataFrame(
    listings,
    geometry=gpd.points_from_xy(listings['longitude'],
                                   listings['latitude'],
                                   crs="EPSG:4326")
)

# Printing the shape of the DataFrame
listings_gpdf.shape
# Out:
# (38792, 76)

# %%
# Focusing on attractions in Manhattan, so we need to create a mask to filter locations 
# in the Manhattan borough
boroughs = gpd.read_file(path + "NYC Boroughs/nybb_22a/nybb.shp")

boroughs = boroughs.to_crs('EPSG:4326')
manhattan = boroughs[boroughs['BoroName']=='Manhattan']

# get the start time
st = time.time()

listings_mask = listings_gpdf.within(manhattan.loc[3, 'geometry'])

listings_manhattan = listings_gpdf.loc[listings_mask]

# get the end time
et = time.time()

# get the execution time
elapsed_time = et - st
print('Execution time:', elapsed_time, 'seconds')
# Out:
# Execution time: 29.858834266662598 seconds

# %%
manhattan.loc[3, 'geometry']
# Out:
# <MULTIPOLYGON (((-74.011 40.684, -74.012 40.684, -74.012 40.684, -74.01 40.6...>

# %%
manhattan['geometry']
# Out:
# 3    MULTIPOLYGON (((-74.01093 40.68449, -74.01193 ...
# Name: geometry, dtype: geometry

# %%
listings_manhattan.shape
# Out:
# (16904, 76)

# %% [markdown]
# # 2.0 Spatial Indexing

# %% [markdown]
# ## 2.1 R-Tree

# %%
geometry = manhattan.loc[3, 'geometry']

# %%
geometry.bounds
# Out:
# (-74.04772947917839, 40.68291657291054, -73.90665087606901, 40.87903763229265)

# %%
# Building the R-tree spatial index
sindex = listings_gpdf.sindex

# get the start time
st = time.time()

# Getting the indexes of the possible matches from the R-tree
#idex_possible_matches = list(sindex.intersection(geometry.bounds))

## BUG FIX??
total_bounds = listings_gpdf.geometry.total_bounds
idex_possible_matches = list(sindex.intersection(total_bounds))

# subsetting the dataframe to be only possible matches
possible_matches_df = listings_gpdf.iloc[idex_possible_matches]

# Performing an intersection to get the precise matches
precise_matches_df = possible_matches_df[possible_matches_df.intersects(geometry)]

## BUG FIX
#precise_matches_df = possible_matches_df[possible_matches_df.intersects(listings_manhattan.geometry)]

# get the end time
et = time.time()

# get the execution time
elapsed_time = et - st
print('Execution time:', elapsed_time, 'seconds')

# %%
precise_matches_df.shape

# %%
## This was not in the original code, but something was missing here, so I added this
print(total_bounds)
# Create a bounding box Polygon
bounding_box = Polygon([(total_bounds[0], total_bounds[1]), 
                        (total_bounds[2], total_bounds[1]), 
                        (total_bounds[2], total_bounds[3]), 
                        (total_bounds[0], total_bounds[3])])
bounding_box
# Out:
# [-74.251907    40.50031443 -73.71365     40.91138   ]
# <POLYGON ((-74.252 40.5, -73.714 40.5, -73.714 40.911, -74.252 40.911, -74.2...>

# %% [markdown]
# ### 2.1.1 R-Tree with Subdivided Polygons

# %%
# Create the subdivided polygons
subdivided_polygon = ox.utils_geo._quadrat_cut_geometry(bounding_box, quadrat_width=0.1) # quadrant_width is in the CRS measurement units (4326:degrees)
subdivided_polygon
# Out:
# <MULTIPOLYGON (((-74.252 40.911, -74.162 40.911, -74.162 40.829, -74.252 40....>

# %%
listings_manhattan.loc[[1,2]]
# Out:
#          id                            listing_url       scrape_id  \
# 5  53903662  https://www.airbnb.com/rooms/53903662  20231001204715
# 6  53722728  https://www.airbnb.com/rooms/53722728  20231001204715
#
#   last_scraped       source  \
# 5   2023-10-02  city scrape
# 6   2023-10-02  city scrape
#
#                                                 name  \
# 5  Condo in New York · ★4.43 · 1 bedroom · 1 bed ...
# 6  Condo in New York · ★4.29 · 1 bedroom · 1 bed ...
#
#                                          description  \
# 5  This room is in a full floor, 4 bedroom apartm...
# 6  This room is in a full floor, 4 bedroom apartm...
#
#                                neighborhood_overview  \
# 5  The East Village is located in Downtown Manhat...
# 6  The East Village is located in Downtown Manhat...
#
#                                          picture_url   host_id  ...  \
# 5  https://a0.muscache.com/pictures/61ebc358-7be7...  74338125  ...
# 6  https://a0.muscache.com/pictures/6633c373-1642...  74338125  ...
#
#   review_scores_location review_scores_value license instant_bookable  \
# 5                   4.85                4.44     NaN                t
# 6                   4.80                4.15     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 5                              2                                           0
# 6                              2                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 5                                            2
# 6                                            2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month  \
# 5                                           0              2.86
# 6                                           0              1.88
#
#                      geometry
# 5  POINT (-73.98691 40.72625)
# 6  POINT (-73.98801 40.72813)
#
# [2 rows x 76 columns]

# %%
listings_gpdf.index
# Out:
# RangeIndex(start=0, stop=38792, step=1)

# %%
listings_gpdf.iloc[idex_possible_matches]
# Out:
#                        id                                      listing_url  \
# 30105            51804585            https://www.airbnb.com/rooms/51804585
# 26785            40197518            https://www.airbnb.com/rooms/40197518
# 27260  918665614477414731  https://www.airbnb.com/rooms/918665614477414731
# 19827            41568108            https://www.airbnb.com/rooms/41568108
# 3577   839814083143454171  https://www.airbnb.com/rooms/839814083143454171
# 27029  839891163018998589  https://www.airbnb.com/rooms/839891163018998589
# 27030  839904583057491087  https://www.airbnb.com/rooms/839904583057491087
# 3076   755100105142935660  https://www.airbnb.com/rooms/755100105142935660
# 21690  585485781418964904  https://www.airbnb.com/rooms/585485781418964904
# 3074   755086539734518870  https://www.airbnb.com/rooms/755086539734518870
# 29629            26452047            https://www.airbnb.com/rooms/26452047
# 21689            14462592            https://www.airbnb.com/rooms/14462592
# 26590  712251477859752098  https://www.airbnb.com/rooms/712251477859752098
# 31940  699158285991699810  https://www.airbnb.com/rooms/699158285991699810
# 26591  712281667658704072  https://www.airbnb.com/rooms/712281667658704072
# 26592  711603369617196627  https://www.airbnb.com/rooms/711603369617196627
# 1748             51608497            https://www.airbnb.com/rooms/51608497
# 22494  770130015451026213  https://www.airbnb.com/rooms/770130015451026213
# 22495  684818345183889619  https://www.airbnb.com/rooms/684818345183889619
# 18208  636102680963588163  https://www.airbnb.com/rooms/636102680963588163
# 18206            48225044            https://www.airbnb.com/rooms/48225044
# 26303  888204046055104522  https://www.airbnb.com/rooms/888204046055104522
# 18207  641863227870851745  https://www.airbnb.com/rooms/641863227870851745
# 18220            52585129            https://www.airbnb.com/rooms/52585129
# 24333  741971895925871723  https://www.airbnb.com/rooms/741971895925871723
# 18221            52584132            https://www.airbnb.com/rooms/52584132
# 18219  858272839740348480  https://www.airbnb.com/rooms/858272839740348480
# 29226  594281876479242562  https://www.airbnb.com/rooms/594281876479242562
#
#             scrape_id last_scraped           source  \
# 30105  20231001204715   2023-10-02      city scrape
# 26785  20231001204715   2023-10-02  previous scrape
# 27260  20231001204715   2023-10-02      city scrape
# 19827  20231001204715   2023-10-02      city scrape
# 3577   20231001204715   2023-10-02      city scrape
# 27029  20231001204715   2023-10-02      city scrape
# 27030  20231001204715   2023-10-02      city scrape
# 3076   20231001204715   2023-10-02      city scrape
# 21690  20231001204715   2023-10-02      city scrape
# 3074   20231001204715   2023-10-02      city scrape
# 29629  20231001204715   2023-10-02      city scrape
# 21689  20231001204715   2023-10-02      city scrape
# 26590  20231001204715   2023-10-02      city scrape
# 31940  20231001204715   2023-10-02  previous scrape
# 26591  20231001204715   2023-10-02      city scrape
# 26592  20231001204715   2023-10-02      city scrape
# 1748   20231001204715   2023-10-02      city scrape
# 22494  20231001204715   2023-10-02      city scrape
# 22495  20231001204715   2023-10-02      city scrape
# 18208  20231001204715   2023-10-02      city scrape
# 18206  20231001204715   2023-10-02      city scrape
# 26303  20231001204715   2023-10-02      city scrape
# 18207  20231001204715   2023-10-02      city scrape
# 18220  20231001204715   2023-10-02      city scrape
# 24333  20231001204715   2023-10-02      city scrape
# 18221  20231001204715   2023-10-02      city scrape
# 18219  20231001204715   2023-10-02      city scrape
# 29226  20231001204715   2023-10-02      city scrape
#
#                                                     name  \
# 30105  casa particular in Staten Island · 1 bedroom ·...
# 26785  Rental unit in Staten Island · ★4.90 · 1 bedro...
# 27260  Townhouse in Staten Island · 3 bedrooms · 4 be...
# 19827  Townhouse in Staten Island · ★5.0 · 1 bedroom ...
# 3577   Home in Staten Island · 3 bedrooms · 4 beds · ...
# 27029  Rental unit in Staten Island · 1 bedroom · 1 b...
# 27030  Rental unit in Staten Island · ★4.88 · 1 bedro...
# 3076   Place to stay in Staten Island · 1 bedroom · 1...
# 21690  Home in Staten Island · 3 bedrooms · 3 beds · ...
# 3074   Place to stay in Staten Island · 1 bedroom · 1...
# 29629  Home in Staten Island · ★3.67 · 1 bedroom · 1 ...
# 21689  Home in New York · ★4.73 · 1 bedroom · 1 bed ·...
# 26590  Home in Staten Island · ★5.0 · 1 bedroom · 1 b...
# 31940  Townhouse in Staten Island · ★4.43 · 1 bedroom...
# 26591  Home in Staten Island · ★4.67 · 1 bedroom · 1 ...
# 26592  Home in Staten Island · ★4.80 · 3 bedrooms · 3...
# 1748   Home in Staten Island · 2 bedrooms · 2 beds · ...
# 22494  Rental unit in Staten Island · ★4.50 · 2 bedro...
# 22495  Rental unit in Staten Island · ★4.86 · 2 bedro...
# 18208  Home in Staten Island · ★3.71 · 1 bedroom · 1 ...
# 18206  Home in Staten Island · ★4.69 · 1 bedroom · 1 ...
# 26303  Rental unit in Staten Island · 1 bedroom · 2 b...
# 18207  Home in Staten Island · ★4.59 · 1 bedroom · 1 ...
# 18220  Home in Staten Island · ★5.0 · 1 bedroom · 1 b...
# 24333  Guest suite in Staten Island · 1 bedroom · 1 b...
# 18221  Home in Staten Island · ★4.94 · 1 bedroom · 1....
# 18219  Rental unit in Staten Island · ★5.0 · 1 bedroo...
# 29226  Townhouse in Staten Island · ★4.74 · 3 bedroom...
#
#                                              description  \
# 30105  Beautiful brand new furnished studio.  Separat...
# 26785  We welcome you to our home! Our house has a st...
# 27260  Three-bedroom home in Staten Island, NY. Maste...
# 19827  A gorgeous one-bedroom apartment located on th...
# 3577   This location is the right place to be for tra...
# 27029  This unique place is a shared living home with...
# 27030  This home is a 3bedroom apartment of which the...
# 3076   COMMERICAL OFFICE LISTING, NO OVERNIGHT STAY. ...
# 21690  Great  for relaxing, enjoy the indoor and outd...
# 3074   COMMERICAL OFFICE LISTING, NO OVERNIGHT STAY. ...
# 29629                                It's a private room
# 21689  A warm comfortable  luxury  one bedroom apartm...
# 26590  You will feel right at home in this quiet peac...
# 31940  Relax with the whole family at this peaceful p...
# 26591  Forget your worries in this spacious and seren...
# 26592  A peaceful,warm,cozy place to relax and  forge...
# 1748   Bring the whole family to this great place wit...
# 22494  Kick back and relax in this calm, stylish spac...
# 22495  Kick back and relax in this calm, stylish spac...
# 18208  close to a commercial district<br />One bus br...
# 18206  Close to stores shopping area 5 min walk to bu...
# 26303  Enjoy a stylish experience at this centrally-l...
# 18207  nearby a commercial district<br />Parking is a...
# 18220  A Beautiful private room with so many amenitie...
# 24333  A very peaceful country like setting in a priv...
# 18221  A Beautiful private room with so many amenitie...
# 18219  Relax at this peaceful place that is furnished...
# 29226  Enjoy a cozy home with your family or friends ...
#
#                                    neighborhood_overview  \
# 30105                                                NaN
# 26785                                                NaN
# 27260                                                NaN
# 19827  Stop&Shop supermarkets, restaurants or bars - ...
# 3577                                                 NaN
# 27029  Very peaceful and quiet neighborhood. Everyone...
# 27030         Very quiet neighborhood to be at all time.
# 3076                                                 NaN
# 21690                                                NaN
# 3074                                                 NaN
# 29629                                                NaN
# 21689  Near all restaurant  , recreation  and snug  h...
# 26590  quite and family oriented. There is a laundrom...
# 31940  Not far from the university of Staten Island. ...
# 26591                                                NaN
# 26592                              Neighborhood is quiet
# 1748                                                 NaN
# 22494                          it's a quite neighborhood
# 22495                                 quiet neighborhood
# 18208                                 Quiet and peaceful
# 18206                        safe and queit neighborhood
# 26303  Mariners Harbor, Staten Island – 15 minute bus...
# 18207  A peaceful, secure neighborhood that is conven...
# 18220                                                NaN
# 24333  it's a very quiet residential block with free ...
# 18221                                                NaN
# 18219                                                NaN
# 29226                                                NaN
#
#                                              picture_url    host_id  ...  \
# 30105  https://a0.muscache.com/pictures/e3ac85e4-8f66...  419687159  ...
# 26785  https://a0.muscache.com/pictures/d7b96269-a110...  212526336  ...
# 27260  https://a0.muscache.com/pictures/miso/Hosting-...  149603923  ...
# 19827  https://a0.muscache.com/pictures/f582cf1c-a5f7...  327542066  ...
# 3577   https://a0.muscache.com/pictures/miso/Hosting-...   48533809  ...
# 27029  https://a0.muscache.com/pictures/miso/Hosting-...  394333507  ...
# 27030  https://a0.muscache.com/pictures/44339b54-44ad...  394333507  ...
# 3076   https://a0.muscache.com/pictures/miso/Hosting-...  425208249  ...
# 21690  https://a0.muscache.com/pictures/f336a135-68bb...   79641851  ...
# 3074   https://a0.muscache.com/pictures/miso/Hosting-...  425208249  ...
# 29629  https://a0.muscache.com/pictures/d910e116-9d35...    3375455  ...
# 21689  https://a0.muscache.com/pictures/42809187-97e0...   79641851  ...
# 26590  https://a0.muscache.com/pictures/miso/Hosting-...  478717835  ...
# 31940  https://a0.muscache.com/pictures/miso/Hosting-...  131000948  ...
# 26591  https://a0.muscache.com/pictures/miso/Hosting-...  478717835  ...
# 26592  https://a0.muscache.com/pictures/miso/Hosting-...  478717835  ...
# 1748   https://a0.muscache.com/pictures/miso/Hosting-...     858318  ...
# 22494  https://a0.muscache.com/pictures/10caf1e8-fdd4...  206642978  ...
# 22495  https://a0.muscache.com/pictures/fc8f82a2-b70f...  206642978  ...
# 18208  https://a0.muscache.com/pictures/miso/Hosting-...  355258878  ...
# 18206  https://a0.muscache.com/pictures/miso/Hosting-...  355258878  ...
# 26303  https://a0.muscache.com/pictures/5ab312bd-7885...  385221913  ...
# 18207  https://a0.muscache.com/pictures/miso/Hosting-...  355258878  ...
# 18220  https://a0.muscache.com/pictures/miso/Hosting-...   42076010  ...
# 24333  https://a0.muscache.com/pictures/775b409b-c27c...  484398197  ...
# 18221  https://a0.muscache.com/pictures/3a6d003b-5af3...   42076010  ...
# 18219  https://a0.muscache.com/pictures/f1fac86b-6754...   42076010  ...
# 29226  https://a0.muscache.com/pictures/miso/Hosting-...   76582389  ...
#
#       review_scores_location review_scores_value             license  \
# 30105                   5.00                5.00                 NaN
# 26785                   5.00                4.97                 NaN
# 27260                   5.00                5.00                 NaN
# 19827                   4.63                4.88                 NaN
# 3577                     NaN                 NaN                 NaN
# 27029                    NaN                1.00                 NaN
# 27030                   4.88                4.88                 NaN
# 3076                     NaN                 NaN                 NaN
# 21690                   4.50                5.00                 NaN
# 3074                     NaN                 NaN                 NaN
# 29629                   4.00                3.67                 NaN
# 21689                   4.28                4.58                 NaN
# 26590                   4.80                5.00                 NaN
# 31940                   4.86                4.43                 NaN
# 26591                   4.89                4.78                 NaN
# 26592                   4.52                4.68                 NaN
# 1748                     NaN                 NaN                 NaN
# 22494                   4.42                4.50                 NaN
# 22495                   4.43                4.71                 NaN
# 18208                   3.57                3.43  OSE-STRREG-0000155
# 18206                   4.46                4.46  OSE-STRREG-0000155
# 26303                    NaN                 NaN                 NaN
# 18207                   4.53                4.65  OSE-STRREG-0000155
# 18220                   5.00                5.00                 NaN
# 24333                    NaN                 NaN                 NaN
# 18221                   4.88                4.94                 NaN
# 18219                   5.00                5.00                 NaN
# 29226                   4.48                4.67                 NaN
#
#       instant_bookable calculated_host_listings_count  \
# 30105                f                              1
# 26785                f                              1
# 27260                t                              1
# 19827                f                              1
# 3577                 f                              1
# 27029                f                              2
# 27030                f                              2
# 3076                 t                              3
# 21690                t                              2
# 3074                 t                              3
# 29629                f                              1
# 21689                f                              2
# 26590                f                              3
# 31940                f                              1
# 26591                f                              3
# 26592                f                              3
# 1748                 f                              1
# 22494                t                              2
# 22495                f                              2
# 18208                f                              3
# 18206                f                              3
# 26303                t                              1
# 18207                f                              3
# 18220                f                              3
# 24333                f                              1
# 18221                f                              3
# 18219                t                              3
# 29226                t                              1
#
#       calculated_host_listings_count_entire_homes  \
# 30105                                           1
# 26785                                           1
# 27260                                           1
# 19827                                           0
# 3577                                            1
# 27029                                           0
# 27030                                           0
# 3076                                            0
# 21690                                           2
# 3074                                            0
# 29629                                           0
# 21689                                           2
# 26590                                           1
# 31940                                           0
# 26591                                           1
# 26592                                           1
# 1748                                            1
# 22494                                           2
# 22495                                           2
# 18208                                           0
# 18206                                           0
# 26303                                           0
# 18207                                           0
# 18220                                           0
# 24333                                           1
# 18221                                           0
# 18219                                           0
# 29226                                           1
#
#       calculated_host_listings_count_private_rooms  \
# 30105                                            0
# 26785                                            0
# 27260                                            0
# 19827                                            1
# 3577                                             0
# 27029                                            2
# 27030                                            2
# 3076                                             0
# 21690                                            0
# 3074                                             0
# 29629                                            1
# 21689                                            0
# 26590                                            2
# 31940                                            1
# 26591                                            2
# 26592                                            2
# 1748                                             0
# 22494                                            0
# 22495                                            0
# 18208                                            3
# 18206                                            3
# 26303                                            1
# 18207                                            3
# 18220                                            3
# 24333                                            0
# 18221                                            3
# 18219                                            3
# 29226                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month  \
# 30105                                           0              0.06
# 26785                                           0              0.66
# 27260                                           0              0.56
# 19827                                           0              5.22
# 3577                                            0               NaN
# 27029                                           0              0.45
# 27030                                           0              1.33
# 3076                                            3               NaN
# 21690                                           0              0.16
# 3074                                            3               NaN
# 29629                                           0              0.07
# 21689                                           0              0.47
# 26590                                           0              0.45
# 31940                                           0              0.53
# 26591                                           0              0.75
# 26592                                           0              1.94
# 1748                                            0               NaN
# 22494                                           0              1.21
# 22495                                           0              0.99
# 18208                                           0              0.44
# 18206                                           0              0.79
# 26303                                           0               NaN
# 18207                                           0              1.07
# 18220                                           0              0.71
# 24333                                           0               NaN
# 18221                                           0              0.70
# 18219                                           0              0.67
# 29226                                           0              3.17
#
#                          geometry
# 30105  POINT (-74.18478 40.59598)
# 26785  POINT (-74.16678 40.60394)
# 27260  POINT (-74.16976 40.60947)
# 19827  POINT (-74.16451 40.61533)
# 3577   POINT (-74.16465 40.61691)
# 27029  POINT (-74.16469 40.61692)
# 27030  POINT (-74.16580 40.61745)
# 3076   POINT (-74.16235 40.62521)
# 21690  POINT (-74.16863 40.62561)
# 3074   POINT (-74.16239 40.62712)
# 29629  POINT (-74.16225 40.62935)
# 21689  POINT (-74.17485 40.63018)
# 26590  POINT (-74.16563 40.63290)
# 31940  POINT (-74.16749 40.63444)
# 26591  POINT (-74.16582 40.63452)
# 26592  POINT (-74.16777 40.63465)
# 1748   POINT (-74.16903 40.63476)
# 22494  POINT (-74.16801 40.63672)
# 22495  POINT (-74.16854 40.63707)
# 18208  POINT (-74.16759 40.63708)
# 18206  POINT (-74.16940 40.63711)
# 26303  POINT (-74.16740 40.63777)
# 18207  POINT (-74.16913 40.63820)
# 18220  POINT (-74.16957 40.63856)
# 24333  POINT (-74.16349 40.63862)
# 18221  POINT (-74.16970 40.64015)
# 18219  POINT (-74.16802 40.64067)
# 29226  POINT (-74.16844 40.64117)
#
# [28 rows x 76 columns]

# %%
# get the start time
st = time.time()

points_in_geometry = pd.DataFrame()
#for geom in subdivided_polygon:
for geom in subdivided_polygon.geoms:
    # add in a slight buffer to account for points falling on the lines of the subdivided polygons
    geom = geom.buffer(1e-14).buffer(0)

    # Getting the indexes of the possible matches from the R-tree
    idex_possible_matches = list(sindex.intersection(geom.bounds))
    possible_matches_df = listings_gpdf.iloc[idex_possible_matches]
    
    # Performing an intersection to get the precise matches
    precise_matches_df = possible_matches_df[possible_matches_df.intersects(geom)]
    #points_in_geometry = points_in_geometry.append(precise_matches_df)
    points_in_geometry = pd.concat([points_in_geometry, precise_matches_df], ignore_index=True)


# get the end time
et = time.time()

# get the execution time
elapsed_time = et - st
print('Execution time:', elapsed_time, 'seconds')
# Out:
# Execution time: 0.4791250228881836 seconds

# %%
points_in_geometry.shape
# Out:
# (38792, 76)

# %%
# WHY DO WE HAVE MANY MORE

# %% [markdown]
# ## 2.2 H3

# %%
# Reference Materials
# https://www.uber.com/blog/h3/
# https://spatialthoughts.com/2020/07/01/point-in-polygon-h3-geopandas/

# %%
# %matplotlib inline 
from h3 import h3
import contextily

# %%
# Set the H3 resolution
h3_resolution = 8
 
# Creating a function to add the H3 identifier to each of the Airbnb Points
def add_h3_id(row):
    return h3.geo_to_h3(
      row.geometry.y, row.geometry.x, h3_level)

# Executing the function
listings_manhattan['h3'] = listings_gpdf.apply(add_h3_id, axis=1)

# Display the dataframe
listings_manhattan.head()

# %%
# Creating a dataframe with the count of airbnb's within each hexagon
airbnb_count = listings_manhattan.groupby(['h3']).h3.agg('count').to_frame('count').reset_index()

# %%
# Defining a function to get the geometry for each of the H3 hexagons
def add_h3_geometry(row):
    points = h3.h3_to_geo_boundary(
      row['h3'], True)
    return Polygon(points)

# Adding the geometry to the airbnb_count dataframe
airbnb_count['geometry'] = airbnb_count.apply(add_geometry, axis=1)

# Converting to a geodataframe
gdf = gpd.GeoDataFrame(counts, crs='EPSG:4326')

# %%
# Plotting a choropleth map of the Airbnb's within each cell
f, ax = plt.subplots(1, figsize=(10, 20))
   
# Plot choropleth of counts
gdf.plot(
    column='count', 
    cmap='coolwarm', 
    scheme='quantiles',
    k=4, 
    edgecolor='white', 
    linewidth=0.1, 
    alpha=0.5,
    legend=True,
    ax=ax
)

# Add basemap
contextily.add_basemap(
    ax,
    crs=gdf.crs,
    source=contextily.providers.Stamen.TonerLite,
)
    
# Remove axis
ax.set_axis_off()

# Display
plt.show()
#f.savefig(path + r"Neighborhood Residuals.png")
